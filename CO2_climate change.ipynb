# %% [markdown]
# #### Explore AI Academy: Final Regression Project

# %% [markdown]
# <div style="font-size: 35px">
#     <font color='Green'> <b>CO2 impact on climate change in Agri-food sector</b></font>

# %% [markdown]
# <p align="center">
#   <img src="agri_image.png" alt="Deforestation (local)" width="800"/>
#
# </p>

# %% [markdown]
# ## 📑 Table of Contents
#
# **📘 1. Project Overview**
#   📖 1.1 Introduction
#   🌍 1.2 Problem Statement
#   🎯 1.3 Objectives
#   📊 1.4 Data Source
#   🌱 1.5 Importance of the Study
#   ❓ 1.6 Key Questions
#   🛠️ 1.7 Methodology Overview
#   🗂️ 1.8 Notebook Structure
#   ✅ 1.9 Expected Outcomes
#
# **⚙️ 2. Importing Packages**
# **📥 3. Loading Data and Preparing Data**
# **🧹 4. Data Cleaning**
# **📊 5. Exploratory Data Analysis (EDA)**
# **🔧 6. Feature Engineering**
# **🤖 7. Modeling**
# **📈 8. Model Performance**
# **🧠 9. You will learn more in Machine Learning Sprints**
# **📝 10. Conclusion**
# **📚 11. References**

# %% [markdown]
# ---
#
# ## 🧭 How to Use This Notebook (for First-Time Users)
#
# > 📌 If you're opening this notebook for the first time:
#
# 1. **Run all code cells** from top to bottom:
#    - In Jupyter: `Kernel > Restart & Run All`
#    - In VS Code: Right-click → `Run All Cells`
#
# 2. Ensure the required dataset files are present:
#    - `co2_emissions_from_agri.csv`
#    - If missing, download from the [GitHub repo](https://github.com/TiffanyWatt/2401PTDS_Regression_Project)
#
# 3. Check that required Python packages are installed:
#    - `pandas`, `numpy`, `matplotlib`, `seaborn`, `scikit-learn`,
#    - If not, install them using:
#      ```bash
#      pip install pandas matplotlib seaborn scikit-learn
#      ```
#
# 4. Follow the numbered sections (1–11) in order for the full workflow.
#
# > 🧠 Outputs you see in this notebook are from a previously run session.
# > To **interact with it**, you must run the cells yourself.
#
# ---

# %% [markdown]
# ## 📘 1. Project Overview
#
# ### 📖 1.1 Introduction
# This notebook explores temperature trends in the agricultural sector using datasets from the Food and Agriculture Organization (FAO) and the Intergovernmental Panel on Climate Change (IPCC). The main aim is to forecast average temperature levels by applying regression techniques in Python.
#
# The dataset contains over 7,000 records with more than 30 features, covering climate, agricultural, and environmental indicators. Python-based tools such as `pandas`, `numpy`, `matplotlib`, `seaborn`, `scikit-learn`, will be used for cleaning, analysis, modeling, and visualization.
#
# ---
#
# ### 🌍 1.2 Problem Statement
# Climate change is a critical challenge for global agriculture. Shifts in average temperature affect crop yields, food security, and the livelihoods of farming communities. Despite extensive research, it remains difficult to:
# - Predict future agricultural temperature changes with accuracy.
# - Understand which environmental factors most strongly drive these changes.
# - Provide stakeholders (farmers, policymakers, businesses) with actionable forecasts to support sustainable strategies.
#
# This project focuses on using regression analysis to forecast agricultural temperature, helping highlight key drivers of change and offering data-driven evidence for decision-making.
#
# ---
#
# ### 🎯 1.3 Objectives
# - Forecast average agricultural temperature using regression models.
# - Perform exploratory data analysis (EDA) to identify important trends and relationships among variables.
# - Apply at least three regression models (e.g., Linear Regression, Ridge/Lasso, Random Forest Regression).
# - Compare model performance using metrics such as RMSE, MAE, and R².
# - Recommend the best-performing model for future forecasting tasks.
# - Present results in a clear, well-documented notebook and slide deck, ensuring reproducibility and team collaboration
#
# ---
#
# ### 📊 1.4 Data Source
# The dataset is sourced from the **Food and Agriculture Organization (FAO)** and the **Intergovernmental Panel on Climate Change (IPCC)**. It provides:
#
# - Agricultural and climate-related variables with 30+ features
# - Approximately 7,000 records spanning multiple regions and years
# - Reliable measures for analyzing temperature patterns and their impact on agriculture
#
# ---
#
# ### 🌱 1.5 Importance of the Study
# Changes in agricultural temperature play a crucial role in shaping food security, crop productivity, and sustainable farming practices. Understanding these trends is essential to:
#
# - Support climate adaptation and mitigation policies
# - Inform agricultural planning and resource allocation
# - Assist policymakers and businesses in developing sustainable strategies
# - Highlight potential risks and opportunities for future agricultural development
#
# ---
#
# ### ❓ 1.6 Key Questions
# This project aims to address:
#
# - Which features have the strongest influence on agricultural temperature changes?
# - How well can regression models predict average agricultural temperature?
# - What patterns can be identified through exploratory data analysis (e.g., correlations, seasonal trends)?
# - Which regression model performs best and why?
#
# ---
#
# ### 🛠️ 1.7 Methodology Overview
# The analysis will involve:
#
# - Importing and exploring the dataset
# - Cleaning and preparing the data for modeling
# - Performing **Exploratory Data Analysis (EDA)** to uncover relationships and trends
# - Building and training at least three regression models (e.g., Linear Regression, Ridge/Lasso, Random Forest Regression)
# - Evaluating model performance using metrics such as **RMSE, MAE, and R²**
# - Selecting the best model and summarizing insights for stakeholders
#
# Visualizations and results will be developed using **pandas**, **matplotlib**, **seaborn**, and **scikit-learn**, with clear documentation at each step.
#
# ---
#
# ### 🗂️ 1.8 Notebook Structure
# - Project Overview
# - Importing Packages
# - Loading the Dataset
# - Data Cleaning and Preprocessing
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Regression Modeling (Linear, Ridge/Lasso, Random Forest, etc.)
# - Model Evaluation and Comparison (RMSE, MAE, R²)
# - Conclusion & Recommendations
# - References
#
# ---
#
# ### ✅ 1.9 Expected Outcomes
# - Clear visualizations showing agricultural temperature patterns over time
# - Identification of variables most strongly influencing temperature changes
# - Regression model outputs with comparisons across different techniques
# - Summary tables of model performance (metrics and insights)
# - Recommendation of the best-performing model for forecasting agricultural temperatures
# - Actionable takeaways for stakeholders, supporting sustainable agricultural planning and climate strategies

# %% [markdown]
# ## 2. Importing Packages <a class="anchor" id="chapter2"></a>
#
# This project uses agricultural and climate data (FAO and IPCC) to forecast **average agricultural temperature**.
# To prepare, clean, analyze, and model the dataset, we will use the following Python libraries:
#
# - **pandas** and **numpy** for data manipulation and analysis
# - **matplotlib** and **seaborn** for data visualization
# - **scikit-learn** for regression modeling, training, and evaluation
# - **scipy** (optional) for statistical analysis

# %%
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/saustin12/data-science-project
#  * branch            main       -> FETCH_HEAD

# %%
# !git add "CO2_climate change".ipynb
# !git commit -m "Updating EDA"
# !git push origin main
# Out:
# warning: in the working copy of 'CO2_climate change.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main b9b3d7e] Updating EDA
#  Committer: Tiffany Watt <Tiffany.Watt@ninetyone.com>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 2281 insertions(+), 5262 deletions(-)
# To https://github.com/TiffanyWatt/2401PTDS_Regression_Project.git
#    7e17b40..b9b3d7e  main -> main

# %%
# Libraries for data loading, manipulation and analysis

# Importing core packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Displays output inline
# %matplotlib inline

# Libraries for Handing Errors
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3. Loading and Preparing Data <a class="anchor" id="chapter3"></a>
#
# The dataset for this project is sourced from the **FAO** and **IPCC**, focusing on agricultural and climate-related indicators. The CSV file, `co2_emissions_from_agri.csv`, contains ~7,000 records and 30+ features.
#
# To prepare the data for analysis, the CSV file is first loaded into a Pandas DataFrame. Initial exploration includes checking the shape, column names, and basic statistics.

# %%
# loading dataset
df_CO2 = pd.read_csv("co2_emissions_from_agri.csv")

# %%
# Display basic info
print("Dataset shape:", df_CO2.shape)
print("\nColumns:\n", df_CO2.columns.tolist())
# Out:
# Dataset shape: (6965, 31)
#
# Columns:
#  ['Area', 'Year', 'Savanna fires', 'Forest fires', 'Crop Residues', 'Rice Cultivation', 'Drained organic soils (CO2)', 'Pesticides Manufacturing', 'Food Transport', 'Forestland', 'Net Forest conversion', 'Food Household Consumption', 'Food Retail', 'On-farm Electricity Use', 'Food Packaging', 'Agrifood Systems Waste Disposal', 'Food Processing', 'Fertilizers Manufacturing', 'IPPU', 'Manure applied to Soils', 'Manure left on Pasture', 'Manure Management', 'Fires in organic soils', 'Fires in humid tropical forests', 'On-farm energy use', 'Rural population', 'Urban population', 'Total Population - Male', 'Total Population - Female', 'total_emission', 'Average Temperature °C']

# %%
# Preview first 5 rows
df_CO2.head()
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Afghanistan  1990        14.7237        0.0557       205.6077
# 1  Afghanistan  1991        14.7237        0.0557       209.4971
# 2  Afghanistan  1992        14.7237        0.0557       196.5341
# 3  Afghanistan  1993        14.7237        0.0557       230.8175
# 4  Afghanistan  1994        14.7237        0.0557       242.0494
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0            686.00                          0.0                 11.807483
# 1            678.16                          0.0                 11.712073
# 2            686.00                          0.0                 11.712073
# 3            686.00                          0.0                 11.712073
# 4            705.60                          0.0                 11.712073
#
#    Food Transport  Forestland  ...  Manure Management  Fires in organic soils  \
# 0         63.1152   -2388.803  ...           319.1763                     0.0
# 1         61.2125   -2388.803  ...           342.3079                     0.0
# 2         53.3170   -2388.803  ...           349.1224                     0.0
# 3         54.3617   -2388.803  ...           352.2947                     0.0
# 4         53.9874   -2388.803  ...           367.6784                     0.0
#
#    Fires in humid tropical forests  On-farm energy use  Rural population  \
# 0                              0.0                 NaN         9655167.0
# 1                              0.0                 NaN        10230490.0
# 2                              0.0                 NaN        10995568.0
# 3                              0.0                 NaN        11858090.0
# 4                              0.0                 NaN        12690115.0
#
#    Urban population  Total Population - Male  Total Population - Female  \
# 0         2593947.0                5348387.0                  5346409.0
# 1         2763167.0                5372959.0                  5372208.0
# 2         2985663.0                6028494.0                  6028939.0
# 3         3237009.0                7003641.0                  7000119.0
# 4         3482604.0                7733458.0                  7722096.0
#
#    total_emission  Average Temperature °C
# 0     2198.963539                0.536167
# 1     2323.876629                0.020667
# 2     2356.304229               -0.259583
# 3     2368.470529                0.101917
# 4     2500.768729                0.372250
#
# [5 rows x 31 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>To prevent any major unnecessary changes occurring to the original data</b> , a copy of the dataframe was made using the df.copy() method and referred to as `df_copy`.
# </div>

# %%
# The copy of the dataframe
df_CO2_copy = df_CO2.copy()

# %% [markdown]
# ### 3.1 Exploring the Dataset
#
# Before visualising the data, it's helpful to first understand its structure and completeness. The following Pandas methods are useful:
#
# - **`.shape`** – Returns the number of rows and columns in the dataset
# - **`.head()` / `.tail()`** – Displays the first or last few rows to preview the data
# - **`.info()`** – Summarises column names, data types, and non-null counts
# - **`.describe()`** – Provides summary statistics for numerical columns (mean, min, max, etc.)
# - **`.nunique()` / `.unique()`** – Shows the number of unique values (e.g. countries, years)
# - **`.isna().sum()`** – Counts missing values in each column to identify data gaps

# %%
# Shape - Returns the number of rows and columns in the dataset  
df_CO2_copy.shape
# Out:
# (6965, 31)

# %%
# Preview – Displays the first or last few rows to preview the data  
df_CO2_copy.head(5)
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Afghanistan  1990        14.7237        0.0557       205.6077
# 1  Afghanistan  1991        14.7237        0.0557       209.4971
# 2  Afghanistan  1992        14.7237        0.0557       196.5341
# 3  Afghanistan  1993        14.7237        0.0557       230.8175
# 4  Afghanistan  1994        14.7237        0.0557       242.0494
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0            686.00                          0.0                 11.807483
# 1            678.16                          0.0                 11.712073
# 2            686.00                          0.0                 11.712073
# 3            686.00                          0.0                 11.712073
# 4            705.60                          0.0                 11.712073
#
#    Food Transport  Forestland  ...  Manure Management  Fires in organic soils  \
# 0         63.1152   -2388.803  ...           319.1763                     0.0
# 1         61.2125   -2388.803  ...           342.3079                     0.0
# 2         53.3170   -2388.803  ...           349.1224                     0.0
# 3         54.3617   -2388.803  ...           352.2947                     0.0
# 4         53.9874   -2388.803  ...           367.6784                     0.0
#
#    Fires in humid tropical forests  On-farm energy use  Rural population  \
# 0                              0.0                 NaN         9655167.0
# 1                              0.0                 NaN        10230490.0
# 2                              0.0                 NaN        10995568.0
# 3                              0.0                 NaN        11858090.0
# 4                              0.0                 NaN        12690115.0
#
#    Urban population  Total Population - Male  Total Population - Female  \
# 0         2593947.0                5348387.0                  5346409.0
# 1         2763167.0                5372959.0                  5372208.0
# 2         2985663.0                6028494.0                  6028939.0
# 3         3237009.0                7003641.0                  7000119.0
# 4         3482604.0                7733458.0                  7722096.0
#
#    total_emission  Average Temperature °C
# 0     2198.963539                0.536167
# 1     2323.876629                0.020667
# 2     2356.304229               -0.259583
# 3     2368.470529                0.101917
# 4     2500.768729                0.372250
#
# [5 rows x 31 columns]

# %%
# Column types and memory info
df_CO2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area                             6965 non-null   object
#  1   Year                             6965 non-null   int64
#  2   Savanna fires                    6934 non-null   float64
#  3   Forest fires                     6872 non-null   float64
#  4   Crop Residues                    5576 non-null   float64
#  5   Rice Cultivation                 6965 non-null   float64
#  6   Drained organic soils (CO2)      6965 non-null   float64
#  7   Pesticides Manufacturing         6965 non-null   float64
#  8   Food Transport                   6965 non-null   float64
#  9   Forestland                       6472 non-null   float64
#  10  Net Forest conversion            6472 non-null   float64
#  11  Food Household Consumption       6492 non-null   float64
#  12  Food Retail                      6965 non-null   float64
#  13  On-farm Electricity Use          6965 non-null   float64
#  14  Food Packaging                   6965 non-null   float64
#  15  Agrifood Systems Waste Disposal  6965 non-null   float64
#  16  Food Processing                  6965 non-null   float64
#  17  Fertilizers Manufacturing        6965 non-null   float64
#  18  IPPU                             6222 non-null   float64
#  19  Manure applied to Soils          6037 non-null   float64
#  20  Manure left on Pasture           6965 non-null   float64
#  21  Manure Management                6037 non-null   float64
#  22  Fires in organic soils           6965 non-null   float64
#  23  Fires in humid tropical forests  6810 non-null   float64
#  24  On-farm energy use               6009 non-null   float64
#  25  Rural population                 6965 non-null   float64
#  26  Urban population                 6965 non-null   float64
#  27  Total Population - Male          6965 non-null   float64
#  28  Total Population - Female        6965 non-null   float64
#  29  total_emission                   6965 non-null   float64
#  30  Average Temperature °C           6965 non-null   float64
# dtypes: float64(29), int64(1), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 3.2 Dataset Features (Data Dictionary)
#
# The dataset contains approximately **7,000 rows** and **30+ features**, with each row representing a unique agricultural and climate observation.
# It combines information from the **FAO** and **IPCC** to support forecasting of average agricultural temperature.
#
# | Column Name            | Description                                                                 |
# |-------------------------|-----------------------------------------------------------------------------|
# | Country / Region        | The country or region of observation (e.g., USA, Sub-Saharan Africa)        |
# | Year                   | Calendar year of the observation                                            |
# | Avg_Temperature        | Average annual agricultural temperature (target variable for regression)     |
# | CO2_Emissions          | CO₂ emissions from agriculture (in metric tons)                             |
# | Precipitation          | Annual precipitation (mm)                                                   |
# | Fertilizer_Use         | Fertilizer consumption (kg per hectare of arable land)                       |
# | Crop_Yield             | Yield of selected crops (e.g., cereals, tonnes per hectare)                  |
# | Other Features (20+)   | Additional climate and agri-food indicators (e.g., land use, irrigation, etc.) |
#
# ---
#
# ### 🔍 Additional Notes:
# - **Dimensions**: ~7,000 rows × 30+ columns
# - **Entities**: Includes multiple countries and regions
# - **Time span**: Multi-year observations (exact years depend on FAO/IPCC coverage)
# - **Missing values**: Present in some variables — will need treatment (drop, impute, or fill)
# - **Data types**:
#   - Country / Region → `object` (string)
#   - Year → `int`
#   - Numerical features (e.g., CO₂ emissions, precipitation, yields) → `float64`
#
# ---
#
# ➡️ This structured format allows for regression analysis to identify the strongest predictors of **average agricultural temperature** and to build models for forecasting.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Things to consider:</b>
# Ensure that you describe the features of your dataset. You can include this information in the project overview or after presenting your features.
# </div>

# %% [markdown]
# ## 4. Data Cleaning <a class="anchor" id="chapter4"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Data cleaning</b> is a crucial step in the data analysis process, involving the correction or removal of incorrect, corrupted, duplicate, or incomplete data within a dataset. Through various techniques such as filling missing values, removing outliers, and standardizing data formats, it ensures the accuracy and reliability of subsequent analyses and decision-making.
# </div>

# %% [markdown]
# #### 4.1 Handling Missing Data:
# To ensure the dataset was complete and ready for regression analysis, missing values were handled in two steps:
#
# 1. **Median by Area (Country/Region):**
#    Missing values in numeric columns were first imputed using the **median within each `Area`**.
#    This preserves local patterns by ensuring each country or region is filled with values that best reflect its own distribution.
#
# 2. **Global Median Fallback:**
# If missing values remained after the group-level imputation (e.g., when a country had insufficient valid entries to calculate a median), these were filled with the global median of the corresponding feature. This guarantees no missing values remain in the dataset.

# %%
# Fill missing values in numeric columns with the median per country
df_CO2_copy = df_CO2_copy.groupby("Area").apply(
    lambda group: group.fillna(group.median(numeric_only=True))
)

# Reset index (optional, depending on your grouping)
df_CO2_copy.reset_index(drop=True, inplace=True)

# Apply global median for any NaNs left
df_CO2_copy = df_CO2_copy.fillna(df_CO2_copy.median(numeric_only=True))

# %%
# Missing values
df_CO2_copy.isnull().sum().sort_values(ascending=False).head(11)
# Out:
# Area                           0
# Year                           0
# Savanna fires                  0
# Forest fires                   0
# Crop Residues                  0
# Rice Cultivation               0
# Drained organic soils (CO2)    0
# Pesticides Manufacturing       0
# Food Transport                 0
# Forestland                     0
# Net Forest conversion          0
# dtype: int64

# %% [markdown]
# #### 4.2 Converting Area to Numeric
#
# The `Area` column contains categorical values representing countries or regions.
# Since regression models require numeric input, this column was converted into numeric form using **one-hot encoding**. This allows the model to capture differences across areas without imposing an artificial ordering.
#
# We then also want to remove all spaces in the column headings as Libraries like `statsmodels` and `scikit-learn` often expect clean variable names without spaces or special characters.

# %%
# Convert 'Area' to numeric using one-hot encoding
df_CO2_copy = pd.get_dummies(df_CO2_copy, columns=['Area'], drop_first=True)

# Check the updated dataframe
df_CO2_copy.head()
# Out:
#    Year  Savanna fires  Forest fires  Crop Residues  Rice Cultivation  \
# 0  1990        14.7237        0.0557       205.6077            686.00
# 1  1991        14.7237        0.0557       209.4971            678.16
# 2  1992        14.7237        0.0557       196.5341            686.00
# 3  1993        14.7237        0.0557       230.8175            686.00
# 4  1994        14.7237        0.0557       242.0494            705.60
#
#    Drained organic soils (CO2)  Pesticides Manufacturing  Food Transport  \
# 0                          0.0                 11.807483         63.1152
# 1                          0.0                 11.712073         61.2125
# 2                          0.0                 11.712073         53.3170
# 3                          0.0                 11.712073         54.3617
# 4                          0.0                 11.712073         53.9874
#
#    Forestland  Net Forest conversion  ...  Area_Uzbekistan  Area_Vanuatu  \
# 0   -2388.803                    0.0  ...            False         False
# 1   -2388.803                    0.0  ...            False         False
# 2   -2388.803                    0.0  ...            False         False
# 3   -2388.803                    0.0  ...            False         False
# 4   -2388.803                    0.0  ...            False         False
#
#    Area_Venezuela (Bolivarian Republic of)  Area_Viet Nam  \
# 0                                    False          False
# 1                                    False          False
# 2                                    False          False
# 3                                    False          False
# 4                                    False          False
#
#    Area_Wallis and Futuna Islands  Area_Western Sahara  Area_Yemen  \
# 0                           False                False       False
# 1                           False                False       False
# 2                           False                False       False
# 3                           False                False       False
# 4                           False                False       False
#
#    Area_Yugoslav SFR  Area_Zambia  Area_Zimbabwe
# 0              False        False          False
# 1              False        False          False
# 2              False        False          False
# 3              False        False          False
# 4              False        False          False
#
# [5 rows x 265 columns]

# %%
df_CO2_copy.columns = [col.replace(" ","_") for col in df_CO2_copy.columns] 
df_CO2_copy.head()
# Out:
#    Year  Savanna_fires  Forest_fires  Crop_Residues  Rice_Cultivation  \
# 0  1990        14.7237        0.0557       205.6077            686.00
# 1  1991        14.7237        0.0557       209.4971            678.16
# 2  1992        14.7237        0.0557       196.5341            686.00
# 3  1993        14.7237        0.0557       230.8175            686.00
# 4  1994        14.7237        0.0557       242.0494            705.60
#
#    Drained_organic_soils_(CO2)  Pesticides_Manufacturing  Food_Transport  \
# 0                          0.0                 11.807483         63.1152
# 1                          0.0                 11.712073         61.2125
# 2                          0.0                 11.712073         53.3170
# 3                          0.0                 11.712073         54.3617
# 4                          0.0                 11.712073         53.9874
#
#    Forestland  Net_Forest_conversion  ...  Area_Uzbekistan  Area_Vanuatu  \
# 0   -2388.803                    0.0  ...            False         False
# 1   -2388.803                    0.0  ...            False         False
# 2   -2388.803                    0.0  ...            False         False
# 3   -2388.803                    0.0  ...            False         False
# 4   -2388.803                    0.0  ...            False         False
#
#    Area_Venezuela_(Bolivarian_Republic_of)  Area_Viet_Nam  \
# 0                                    False          False
# 1                                    False          False
# 2                                    False          False
# 3                                    False          False
# 4                                    False          False
#
#    Area_Wallis_and_Futuna_Islands  Area_Western_Sahara  Area_Yemen  \
# 0                           False                False       False
# 1                           False                False       False
# 2                           False                False       False
# 3                           False                False       False
# 4                           False                False       False
#
#    Area_Yugoslav_SFR  Area_Zambia  Area_Zimbabwe
# 0              False        False          False
# 1              False        False          False
# 2              False        False          False
# 3              False        False          False
# 4              False        False          False
#
# [5 rows x 265 columns]

# %% [markdown]
# #### <a href=#cont>Back to Table of Contents</a>
#
# ---

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA) <a class="anchor" id="chapter5"></a>
#
#
# To give a better understanding of the variables and the relationships between them, we set out to do an **Exploratory Data Analysis (EDA)** of our dataset. The main tasks includes investigating and summarizing the dataframe's main characteristics by data visualization methods and statistical analyses. Furthermore, investigating the dataset’s key features, summarizing its central characteristics, and employing both data visualisation techniques and statistical analyses to draw meaningful insights that can guide further research and data-driven decision making.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.1. Summary Statistics

# %%
# Summary statistics
df_CO2_copy.describe()
# Out:
#               Year  Savanna_fires  Forest_fires  Crop_Residues  \
# count  6965.000000    6965.000000   6965.000000    6965.000000
# mean   2005.124910    1183.108924    907.034122     816.087597
# std       8.894665    5235.194053   3696.660308    3331.005032
# min    1990.000000       0.000000      0.000000       0.000200
# 25%    1997.000000       0.000000      0.000000      17.232500
# 50%    2005.000000       1.651850      0.517900      93.921450
# 75%    2013.000000     108.361700     61.237200     264.718000
# max    2020.000000  114616.401100  52227.630600   33490.074100
#
#        Rice_Cultivation  Drained_organic_soils_(CO2)  \
# count       6965.000000                  6965.000000
# mean        4259.666673                  3503.228636
# std        17613.825187                 15861.445678
# min            0.000000                     0.000000
# 25%          181.260800                     0.000000
# 50%          534.817400                     0.000000
# 75%         1536.640000                   690.408800
# max       164915.255600                241025.069600
#
#        Pesticides_Manufacturing  Food_Transport     Forestland  \
# count               6965.000000     6965.000000    6965.000000
# mean                 333.418393     1939.581760  -16570.808969
# std                 1429.159367     5616.748808   79013.974879
# min                    0.000000        0.000100 -797183.079000
# 25%                    6.000000       27.958600   -2299.387200
# 50%                   13.000000      204.962800     -62.920000
# 75%                  116.325487     1207.000900       0.000000
# max                16459.000000    67945.765000  171121.076000
#
#        Net_Forest_conversion  ...  Manure_Management  Fires_in_organic_soils  \
# count           6.965000e+03  ...        6965.000000             6965.000000
# mean            1.636262e+04  ...        1997.280013             1210.315532
# std             9.761518e+04  ...        7460.746658            22669.847760
# min             0.000000e+00  ...           0.432900                0.000000
# 25%             0.000000e+00  ...          51.893500                0.000000
# 50%             4.444000e+01  ...         269.187400                0.000000
# 75%             3.830905e+03  ...         883.170300                0.000000
# max             1.605106e+06  ...       70592.646500           991717.543100
#
#        Fires_in_humid_tropical_forests  On-farm_energy_use  Rural_population  \
# count                      6965.000000         6965.000000      6.965000e+03
# mean                        653.577094         2615.956025      1.785774e+07
# std                        3229.846962        11780.187431      8.901521e+07
# min                           0.000000            0.031900      0.000000e+00
# 25%                           0.000000           17.228100      9.731100e+04
# 50%                           0.000000          135.546100      1.595322e+06
# 75%                           6.941800          847.809000      8.177340e+06
# max                       51771.256800       248879.176900      9.000991e+08
#
#        Urban_population  Total_Population_-_Male  Total_Population_-_Female  \
# count      6.965000e+03             6.965000e+03               6.965000e+03
# mean       1.693230e+07             1.761963e+07               1.732447e+07
# std        6.574362e+07             7.603993e+07               7.251711e+07
# min        0.000000e+00             2.500000e+02               2.700000e+02
# 25%        2.173860e+05             2.013260e+05               2.078900e+05
# 50%        2.357581e+06             2.469660e+06               2.444135e+06
# 75%        8.277123e+06             9.075924e+06               9.112588e+06
# max        9.020778e+08             7.435866e+08               7.133419e+08
#
#        total_emission  Average_Temperature_°C
# count    6.965000e+03             6965.000000
# mean     6.409124e+04                0.872989
# std      2.283130e+05                0.555930
# min     -3.918841e+05               -1.415833
# 25%      5.221244e+03                0.511333
# 50%      1.214765e+04                0.834300
# 75%      3.513973e+04                1.206750
# max      3.115114e+06                3.558083
#
# [8 rows x 30 columns]

# %% [markdown]
# ### 5.2. Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df_CO2_copy['Average_Temperature_°C'], kde=True)
plt.show()

# %% [markdown]
# ### 5.2. Bivariate Analysis

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_CO2_copy.corr(), cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# ### 5.3. Trends Over Time

# %%
sns.lineplot(x='Year', y='Average_Temperature_°C', data=df_CO2_copy)
plt.show()

# %% [markdown]
# ### 5.4. Geographic / Regional Insights

# %%
df_CO2.groupby("Area")["Average Temperature °C"].mean().sort_values(ascending=False).head(20)
# Out:
# Area
# Luxembourg            1.545921
# Serbia                1.526917
# Estonia               1.522491
# Belarus               1.495724
# Belgium               1.485413
# Latvia                1.484609
# Russian Federation    1.483595
# Montenegro            1.458567
# Finland               1.452164
# Lithuania             1.439224
# Slovenia              1.437799
# Mongolia              1.404602
# Austria               1.393145
# Czechia               1.381616
# Sweden                1.367548
# Mauritania            1.351957
# Liechtenstein         1.349468
# Switzerland           1.347153
# Germany               1.325390
# Kuwait                1.309296
# Name: Average Temperature °C, dtype: float64

# %% [markdown]
# ## EDA Summary
#
# The exploratory data analysis provided several key insights into the dataset:
#
# - **Data coverage**:
#   The dataset spans from 1990 to 2020 with ~7,000 observations and 30+ features capturing agricultural, environmental, and demographic factors.
#
# - **Summary statistics**:
#   - Many predictors have wide ranges and skewed distributions (e.g., `Rice_Cultivation`, `CO₂ emissions from drained soils`).
#   - Several features contain zeros, suggesting some countries/regions do not report or engage in certain activities.
#   - The target variable (`Average_Temperature_°C`) appears normally distributed around 1 °C with modest variation.
#
# - **Univariate patterns**:
#   - Temperature values cluster near the mean, with relatively few extreme outliers.
#   - Predictors like `Savanna_fires` and `Rice_Cultivation` are highly skewed, indicating the need for transformations or scaling during regression.
#
# - **Bivariate relationships**:
#   - Correlation analysis revealed strong dependencies among industrial/agricultural production variables (e.g., `Food_Packaging`, `Food_Processing`, `Fertilizers_Manufacturing`, and `Urban_population`).
#   - These correlations highlight potential multicollinearity issues, later addressed with correlation filtering and VIF checks.
#   - `Average_Temperature_°C` shows weaker but consistent correlations with emissions- and land-use related features.
#
# - **Time trends**:
#   - A clear upward trajectory in `Average_Temperature_°C` between 1990 and 2020.
#   - The increase accelerates after ~2005, consistent with broader climate change evidence.
#
# - **Regional insights**:
#   - Northern and Eastern European countries (Luxembourg, Estonia, Serbia, Belarus) appear at the top of the ranking for highest average temperatures in this dataset.
#   - This highlights both regional variation and possible reporting differences in agricultural and environmental factors.
#
# **Conclusion:**
# The EDA stage confirmed that the dataset is rich but complex, with highly correlated predictors and strong temporal trends. These findings motivated careful feature selection, scaling, and multicollinearity control before regression modeling.

# %% [markdown]
# ### 6. Feature Engineering (H2) <a class="anchor" id="chapter6"></a>

# %% [markdown]
# ### 6.1. Correlations and model structure
#
# 🔎 Before building regression models, it is important to examine how the independent variables relate to each other and to the dependent variable (`Average_Temperature_°C`).
#
# - Using the cleaned and encoded DataFrame, we can structure a regression model where `Average_Temperature_°C` (dependent variable) is predicted as a function of multiple independent variables (e.g., CO2 emissions, precipitation, fertilizer use, crop yield, and dummy variables for `Area`).
# - To simplify the modeling process, we first **reorder the columns** so that the dependent variable is placed as the last column in the DataFrame. This makes it easier to split predictors (`X`) and the target (`y`) for regression.

# %%
# Move dependent variable 'Average_Temperature_°C' to the last column
column_titles = [col for col in df_CO2_copy.columns if col!= 'Average_Temperature_°C'] + ['Average_Temperature_°C']
df_CO2_copy = df_CO2_copy.reindex(columns=column_titles)

df_CO2_copy.head()
# Out:
#    Year  Savanna_fires  Forest_fires  Crop_Residues  Rice_Cultivation  \
# 0  1990        14.7237        0.0557       205.6077            686.00
# 1  1991        14.7237        0.0557       209.4971            678.16
# 2  1992        14.7237        0.0557       196.5341            686.00
# 3  1993        14.7237        0.0557       230.8175            686.00
# 4  1994        14.7237        0.0557       242.0494            705.60
#
#    Drained_organic_soils_(CO2)  Pesticides_Manufacturing  Food_Transport  \
# 0                          0.0                 11.807483         63.1152
# 1                          0.0                 11.712073         61.2125
# 2                          0.0                 11.712073         53.3170
# 3                          0.0                 11.712073         54.3617
# 4                          0.0                 11.712073         53.9874
#
#    Forestland  Net_Forest_conversion  ...  Area_Vanuatu  \
# 0   -2388.803                    0.0  ...         False
# 1   -2388.803                    0.0  ...         False
# 2   -2388.803                    0.0  ...         False
# 3   -2388.803                    0.0  ...         False
# 4   -2388.803                    0.0  ...         False
#
#    Area_Venezuela_(Bolivarian_Republic_of)  Area_Viet_Nam  \
# 0                                    False          False
# 1                                    False          False
# 2                                    False          False
# 3                                    False          False
# 4                                    False          False
#
#    Area_Wallis_and_Futuna_Islands  Area_Western_Sahara  Area_Yemen  \
# 0                           False                False       False
# 1                           False                False       False
# 2                           False                False       False
# 3                           False                False       False
# 4                           False                False       False
#
#    Area_Yugoslav_SFR  Area_Zambia  Area_Zimbabwe  Average_Temperature_°C
# 0              False        False          False                0.536167
# 1              False        False          False                0.020667
# 2              False        False          False               -0.259583
# 3              False        False          False                0.101917
# 4              False        False          False                0.372250
#
# [5 rows x 265 columns]

# %% [markdown]
# ### 6.1a Create and visualise the correlation matrix
#
# This makes a **heatmap visualisation** representing a **correlation matrix** of our data easier to interpret:

# %%
# The correlation matrix
df_CO2_copy.corr()
# Out:
#                             Year  Savanna_fires  Forest_fires  Crop_Residues  \
# Year                    1.000000      -0.011868     -0.008791       0.028407
# Savanna_fires          -0.011868       1.000000      0.507466       0.038374
# Forest_fires           -0.008791       0.507466      1.000000       0.088360
# Crop_Residues           0.028407       0.038374      0.088360       1.000000
# Rice_Cultivation        0.001641      -0.030713      0.069993       0.823538
# ...                          ...            ...           ...            ...
# Area_Yemen             -0.000939      -0.015112     -0.016407      -0.015192
# Area_Yugoslav_SFR      -0.027868      -0.003774     -0.004031       0.000662
# Area_Zambia            -0.000939       0.174979      0.313766      -0.014243
# Area_Zimbabwe          -0.000939       0.011427     -0.012962      -0.014082
# Average_Temperature_°C  0.545932      -0.046772     -0.039373       0.025365
#
#                         Rice_Cultivation  Drained_organic_soils_(CO2)  \
# Year                            0.001641                     0.004470
# Savanna_fires                  -0.030713                     0.017093
# Forest_fires                    0.069993                     0.108601
# Crop_Residues                   0.823538                     0.217778
# Rice_Cultivation                1.000000                     0.236545
# ...                                  ...                          ...
# Area_Yemen                     -0.014040                    -0.014769
# Area_Yugoslav_SFR              -0.004033                    -0.003448
# Area_Zambia                    -0.016038                     0.046318
# Area_Zimbabwe                  -0.016160                    -0.014769
# Average_Temperature_°C         -0.022532                     0.029030
#
#                         Pesticides_Manufacturing  Food_Transport  Forestland  \
# Year                                    0.023444        0.060122    0.003391
# Savanna_fires                           0.061007        0.070653   -0.062029
# Forest_fires                            0.053654        0.072137   -0.154867
# Crop_Residues                           0.876780        0.771446   -0.741139
# Rice_Cultivation                        0.596904        0.433016   -0.506999
# ...                                          ...             ...         ...
# Area_Yemen                             -0.014859       -0.015741    0.014024
# Area_Yugoslav_SFR                      -0.003515       -0.000418    0.001229
# Area_Zambia                            -0.013867       -0.021435    0.014024
# Area_Zimbabwe                          -0.013049       -0.020327    0.024545
# Average_Temperature_°C                  0.027960        0.075724   -0.052119
#
#                         Net_Forest_conversion  ...  Area_Vanuatu  \
# Year                                -0.022859  ...     -0.000939
# Savanna_fires                        0.228620  ...     -0.015111
# Forest_fires                         0.422390  ...     -0.016394
# Crop_Residues                        0.129458  ...     -0.016381
# Rice_Cultivation                     0.065209  ...     -0.013875
# ...                                       ...  ...           ...
# Area_Yemen                          -0.011209  ...     -0.004471
# Area_Yugoslav_SFR                   -0.002773  ...     -0.001133
# Area_Zambia                         -0.005319  ...     -0.004471
# Area_Zimbabwe                       -0.003898  ...     -0.004471
# Average_Temperature_°C              -0.027368  ...     -0.038681
#
#                         Area_Venezuela_(Bolivarian_Republic_of)  \
# Year                                                  -0.000939
# Savanna_fires                                          0.005598
# Forest_fires                                          -0.004298
# Crop_Residues                                         -0.013316
# Rice_Cultivation                                      -0.011540
# ...                                                         ...
# Area_Yemen                                            -0.004471
# Area_Yugoslav_SFR                                     -0.001133
# Area_Zambia                                           -0.004471
# Area_Zimbabwe                                         -0.004471
# Average_Temperature_°C                                -0.015565
#
#                         Area_Viet_Nam  Area_Wallis_and_Futuna_Islands  \
# Year                        -0.000939                       -0.000939
# Savanna_fires               -0.012531                       -0.015112
# Forest_fires                -0.001722                       -0.016407
# Crop_Residues                0.028954                       -0.014497
# Rice_Cultivation             0.120760                       -0.003115
# ...                               ...                             ...
# Area_Yemen                  -0.004471                       -0.004471
# Area_Yugoslav_SFR           -0.001133                       -0.001133
# Area_Zambia                 -0.004471                       -0.004471
# Area_Zimbabwe               -0.004471                       -0.004471
# Average_Temperature_°C      -0.021017                       -0.035535
#
#                         Area_Western_Sahara  Area_Yemen  Area_Yugoslav_SFR  \
# Year                              -0.000939   -0.000939          -0.027868
# Savanna_fires                     -0.015112   -0.015112          -0.003774
# Forest_fires                      -0.016407   -0.016407          -0.004031
# Crop_Residues                     -0.016379   -0.015192           0.000662
# Rice_Cultivation                  -0.012698   -0.014040          -0.004033
# ...                                     ...         ...                ...
# Area_Yemen                        -0.004471    1.000000          -0.001133
# Area_Yugoslav_SFR                 -0.001133   -0.001133           1.000000
# Area_Zambia                       -0.004471   -0.004471          -0.001133
# Area_Zimbabwe                     -0.004471   -0.004471          -0.001133
# Average_Temperature_°C             0.049889   -0.004838          -0.017849
#
#                         Area_Zambia  Area_Zimbabwe  Average_Temperature_°C
# Year                      -0.000939      -0.000939                0.545932
# Savanna_fires              0.174979       0.011427               -0.046772
# Forest_fires               0.313766      -0.012962               -0.039373
# Crop_Residues             -0.014243      -0.014082                0.025365
# Rice_Cultivation          -0.016038      -0.016160               -0.022532
# ...                             ...            ...                     ...
# Area_Yemen                -0.004471      -0.004471               -0.004838
# Area_Yugoslav_SFR         -0.001133      -0.001133               -0.017849
# Area_Zambia                1.000000      -0.004471               -0.027999
# Area_Zimbabwe             -0.004471       1.000000               -0.066460
# Average_Temperature_°C    -0.027999      -0.066460                1.000000
#
# [265 rows x 265 columns]

# %%
# The correlation heatmap
from statsmodels.graphics.correlation import plot_corr

fig = plt.figure(figsize=(15,15));
ax = fig.add_subplot(111);
plot_corr(df_CO2_copy.corr(), xnames = df_CO2_copy.corr().columns, ax = ax);

# %% [markdown]
# Findings:
#
# We can see from the correlations that it's not the best idea to keep all of the dummy variables.
#
# If we use all of these variables, we're effectively working with **superfluous or redundant information**.

# %% [markdown]
# ### 6.1b Fitting the model using `statsmodels.OLS`
#
# #### Generating the regression string

# %%
import statsmodels.api as sm

# Copy dataset
df_CO2_model = df_CO2_copy.copy()

# Dependent variable
y_name = 'Average_Temperature_°C'

# Independent variables
X_names = [col for col in df_CO2_model.columns if col != y_name]

# Define X and y
X = df_CO2_model[X_names].astype(float).to_numpy()
y = df_CO2_model[y_name].astype(float).to_numpy()

# Add constant
X = sm.add_constant(X, has_constant='add')

# %%
# Build the OLS formula string " y ~ X "
formula_str = y_name+" ~ "+" + ".join(X_names);
print('Formula:\n\t {}'.format(formula_str))
# Out:
# Formula:
# 	 Average_Temperature_°C ~ Year + Savanna_fires + Forest_fires + Crop_Residues + Rice_Cultivation + Drained_organic_soils_(CO2) + Pesticides_Manufacturing + Food_Transport + Forestland + Net_Forest_conversion + Food_Household_Consumption + Food_Retail + On-farm_Electricity_Use + Food_Packaging + Agrifood_Systems_Waste_Disposal + Food_Processing + Fertilizers_Manufacturing + IPPU + Manure_applied_to_Soils + Manure_left_on_Pasture + Manure_Management + Fires_in_organic_soils + Fires_in_humid_tropical_forests + On-farm_energy_use + Rural_population + Urban_population + Total_Population_-_Male + Total_Population_-_Female + total_emission + Area_Albania + Area_Algeria + Area_American_Samoa + Area_Andorra + Area_Angola + Area_Anguilla + Area_Antigua_and_Barbuda + Area_Argentina + Area_Armenia + Area_Aruba + Area_Australia + Area_Austria + Area_Azerbaijan + Area_Bahamas + Area_Bahrain + Area_Bangladesh + Area_Barbados + Area_Belarus + Area_Belgium + Area_Belgium-Luxembourg + Area_Belize + Area_Benin + Area_Bermuda + Area_Bhutan + Area_Bolivia_(Plurinational_State_of) + Area_Bosnia_and_Herzegovina + Area_Botswana + Area_Brazil + Area_British_Virgin_Islands + Area_Brunei_Darussalam + Area_Bulgaria + Area_Burkina_Faso + Area_Burundi + Area_Cabo_Verde + Area_Cambodia + Area_Cameroon + Area_Canada + Area_Cayman_Islands + Area_Central_African_Republic + Area_Chad + Area_Channel_Islands + Area_Chile + Area_China + Area_China,_Hong_Kong_SAR + Area_China,_Macao_SAR + Area_China,_Taiwan_Province_of + Area_China,_mainland + Area_Colombia + Area_Comoros + Area_Congo + Area_Cook_Islands + Area_Costa_Rica + Area_Croatia + Area_Cuba + Area_Cyprus + Area_Czechia + Area_Czechoslovakia + Area_Democratic_People's_Republic_of_Korea + Area_Democratic_Republic_of_the_Congo + Area_Denmark + Area_Djibouti + Area_Dominica + Area_Dominican_Republic + Area_Ecuador + Area_Egypt + Area_El_Salvador + Area_Equatorial_Guinea + Area_Eritrea + Area_Estonia + Area_Eswatini + Area_Ethiopia + Area_Ethiopia_PDR + Area_Falkland_Islands_(Malvinas) + Area_Faroe_Islands + Area_Fiji + Area_Finland + Area_France + Area_French_Polynesia + Area_Gabon + Area_Gambia + Area_Georgia + Area_Germany + Area_Ghana + Area_Gibraltar + Area_Greece + Area_Greenland + Area_Grenada + Area_Guadeloupe + Area_Guam + Area_Guatemala + Area_Guinea + Area_Guinea-Bissau + Area_Guyana + Area_Haiti + Area_Holy_See + Area_Honduras + Area_Hungary + Area_Iceland + Area_India + Area_Indonesia + Area_Iran_(Islamic_Republic_of) + Area_Iraq + Area_Ireland + Area_Isle_of_Man + Area_Israel + Area_Italy + Area_Jamaica + Area_Japan + Area_Jordan + Area_Kazakhstan + Area_Kenya + Area_Kiribati + Area_Kuwait + Area_Kyrgyzstan + Area_Lao_People's_Democratic_Republic + Area_Latvia + Area_Lebanon + Area_Lesotho + Area_Liberia + Area_Libya + Area_Liechtenstein + Area_Lithuania + Area_Luxembourg + Area_Madagascar + Area_Malawi + Area_Malaysia + Area_Maldives + Area_Mali + Area_Malta + Area_Marshall_Islands + Area_Martinique + Area_Mauritania + Area_Mauritius + Area_Mayotte + Area_Mexico + Area_Micronesia_(Federated_States_of) + Area_Monaco + Area_Mongolia + Area_Montenegro + Area_Montserrat + Area_Morocco + Area_Mozambique + Area_Myanmar + Area_Namibia + Area_Nauru + Area_Nepal + Area_Netherlands_(Kingdom_of_the) + Area_Netherlands_Antilles_(former) + Area_New_Caledonia + Area_New_Zealand + Area_Nicaragua + Area_Niger + Area_Nigeria + Area_Niue + Area_North_Macedonia + Area_Northern_Mariana_Islands + Area_Norway + Area_Oman + Area_Pacific_Islands_Trust_Territory + Area_Pakistan + Area_Palau + Area_Palestine + Area_Panama + Area_Papua_New_Guinea + Area_Paraguay + Area_Peru + Area_Philippines + Area_Poland + Area_Portugal + Area_Puerto_Rico + Area_Qatar + Area_Republic_of_Korea + Area_Republic_of_Moldova + Area_Romania + Area_Russian_Federation + Area_Rwanda + Area_Saint_Helena,_Ascension_and_Tristan_da_Cunha + Area_Saint_Kitts_and_Nevis + Area_Saint_Lucia + Area_Saint_Pierre_and_Miquelon + Area_Saint_Vincent_and_the_Grena ...

# %% [markdown]
# #### Fitting the model

# %%
# Fit the OLS regression
model = sm.OLS(y, X)
fitted = model.fit()

# Output the summary
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                
# x234           0.0466      0.103      0.451      0.652      -0.156       0.249
# x235           0.0561      0.103      0.542      0.588      -0.147       0.259
# x236           0.5784      0.275      2.105      0.035       0.040       1.117
# x237          -0.2915      0.106     -2.740      0.006      -0.500      -0.083
# x238          -0.0802      0.103     -0.782      0.434      -0.281       0.121
# x239          -0.2223      0.115     -1.937      0.053      -0.447       0.003
# x240          -0.2448      0.104     -2.356      0.019      -0.449      -0.041
# x241          -0.3197      0.116     -2.759      0.006      -0.547      -0.093
# x242           0.3894      0.104      3.757      0.000       0.186       0.593
# x243           0.2952      0.105      2.799      0.005       0.088       0.502
# x244           0.0470      0.107      0.440      0.660      -0.162       0.256
# x245          -0.2425      0.104     -2.323      0.020      -0.447      -0.038
# x246           4.8910      1.320      3.704      0.000       2.303       7.480
# x247           0.0039      0.107      0.036      0.971      -0.207       0.215
# x248           0.8673      0.180      4.826      0.000       0.515       1.220
# x249          -0.2387      0.115     -2.081      0.037      -0.464      -0.014
# x250           0.4908      0.165      2.984      0.003       0.168       0.813
# x251          -0.1562      0.121     -1.288      0.198      -0.394       0.082
# x252          -0.3381      0.123     -2.745      0.006      -0.580      -0.097
# x253           2.8108      0.788      3.565      0.000       1.265       4.356
# x254          -0.2815      0.107     -2.623      0.009      -0.492      -0.071
# x255           0.3590      0.109      3.292      0.001       0.145       0.573
# x256          -0.3124      0.105     -2.988      0.003      -0.517      -0.107
# x257          -0.1109      0.113     -0.985      0.324      -0.332       0.110
# x258           0.6287      0.234      2.689      0.007       0.170       1.087
# x259          -0.4342      0.122     -3.571      0.000      -0.673      -0.196
# x260           0.2387      0.122      1.959      0.050      -0.000       0.478
# x261          -0.0063      0.102     -0.062      0.951      -0.207       0.194
# x262           0.1630      0.289      0.564      0.573      -0.404       0.730
# x263          -0.2633      0.151     -1.749      0.080      -0.558       0.032
# x264          -0.4801      0.103     -4.650      0.000      -0.682      -0.278
# ==============================================================================
# Omnibus:                      569.892   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2173.377
# Skew:                          -0.346   Prob(JB):                         0.00
# Kurtosis:                       5.648   Cond. No.                     8.07e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.07e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Findings:
#
# - The model fits reasonably well (R² ~ 0.53) but multicollinearity is a concern.
#
# - We will need to check correlations or calculate VIF (Variance Inflation Factor) to identify overlapping predictors.
#
# - After removing or combining redundant variables, the model will likely become more stable and easier to interpret.

# %% [markdown]
# ### Variable selection by correlation and significance
#
# 🔎 With 264 predictor variables available, it is important to identify which ones contribute most to explaining variations in **Average_Temperature_°C**.
#
# Two main approaches guide variable selection:
#
# 1. **Correlation Analysis**
#    - Examine the **correlation coefficients** between `Average_Temperature_°C` and each independent variable.
#    - Select those with the **strongest correlations** (both positive and negative), as they are more likely to influence temperature.
#    - This helps narrow down predictors before modeling.
#
# 2. **Statistical Significance in Regression**
#    - From the regression output, consider predictors with **low p-values (typically < 0.05)**.
#    - These variables are statistically significant and have a measurable impact on temperature.
#    - Coefficients also reveal whether the relationship is positive or negative.
#
# ➡️ By combining correlation strength with statistical significance, we can select a smaller, more reliable set of predictors. This reduces multicollinearity, improves model interpretability, and helps avoid overfitting.

# %%
# Calculate correlations between predictor variables and the response variable
corrs = df_CO2_model.corr()['Average_Temperature_°C'].sort_values(ascending=False)

# %%
from scipy.stats import pearsonr

# Build a dictionary of correlation coefficients and p-values
dict_cp = {}

column_titles = [col for col in corrs.index if col!= 'Average_Temperature_°C']

for col in column_titles:
    p_val = round(pearsonr(df_CO2_model[col], df_CO2_model['Average_Temperature_°C'])[1],6)
    dict_cp[col] = {'Correlation_Coefficient':corrs[col],
                    'P_Value':p_val}
    
df_cp = pd.DataFrame(dict_cp).T
df_cp_sorted = df_cp.sort_values('P_Value')
df_cp_sorted[df_cp_sorted['P_Value']<0.05]
# Out:
#                         Correlation_Coefficient   P_Value
# Year                                   0.545932  0.000000
# Food_Transport                         0.075724  0.000000
# Area_Estonia                           0.075550  0.000000
# Food_Retail                            0.073404  0.000000
# Area_Belarus                           0.072437  0.000000
# ...                                         ...       ...
# Area_Dominica                         -0.024337  0.042250
# Area_Gibraltar                         0.024139  0.043957
# Area_Saint_Lucia                      -0.024108  0.044229
# Area_Channel_Islands                   0.023988  0.045295
# Fires_in_organic_soils                -0.023731  0.047651
#
# [120 rows x 2 columns]

# %% [markdown]
# Now, we've got a **sorted list of the p-values and correlation coefficients** for each of the features, when considered on their own.
#
# Let's keep only the variables that have a significant correlation with the dependent variable. We'll put them into an independent variable DataFrame `X`:

# %%
# The dependent variable remains the same:
y_data = df_CO2_model[y_name]  # y_name = 'Average_Temperature_°C'

# Model building – Independent Variable (IV) DataFrame
X_names = list(df_cp[df_cp['P_Value'] < 0.05].index)
X_data = df_CO2_model[X_names]

# %% [markdown]
# ### Finding and removing the highly correlated features
#
# We also need to look for predictor variable pairs which have a **high correlation with each other** to avoid **autocorrelation**.

# %%
import numpy as np
import pandas as pd

target = "Average_Temperature_°C"

# 1. Compute correlation matrix of predictors
X = df_CO2_model.drop(columns=[target])
corr_matrix = X.corr()

# 2. Find highly correlated pairs (off-diagonal)
threshold = 0.9
corr_pairs = []

for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            var1 = corr_matrix.columns[i]
            var2 = corr_matrix.columns[j]
            corr_val = corr_matrix.iloc[i, j]
            corr_pairs.append((var1, var2, corr_val))

# 3. Create DataFrame of highly correlated pairs
high_corr_df = pd.DataFrame(corr_pairs, columns=["Variable_1", "Variable_2", "Correlation_between_vars"])

# 4. Add correlation of each variable with the target
corr_with_target = df_CO2_model.corr()[target]

high_corr_df["Var1_to_Target"] = high_corr_df["Variable_1"].map(corr_with_target)
high_corr_df["Var2_to_Target"] = high_corr_df["Variable_2"].map(corr_with_target)

# 5. Sort by absolute correlation strength
high_corr_df = high_corr_df.sort_values(by="Correlation_between_vars", key=lambda x: abs(x), ascending=False)

high_corr_df.head(20)
# Out:
#                          Variable_1                       Variable_2  \
# 45          Total_Population_-_Male        Total_Population_-_Female
# 14       Food_Household_Consumption                             IPPU
# 33          Manure_applied_to_Soils                Manure_Management
# 40                 Rural_population          Total_Population_-_Male
# 41                 Rural_population        Total_Population_-_Female
# 26  Agrifood_Systems_Waste_Disposal        Total_Population_-_Female
# 3                     Crop_Residues                Manure_Management
# 21                   Food_Packaging                             IPPU
# 25  Agrifood_Systems_Waste_Disposal          Total_Population_-_Male
# 11       Food_Household_Consumption                   Food_Packaging
# 24  Agrifood_Systems_Waste_Disposal                 Urban_population
# 20                   Food_Packaging        Fertilizers_Manufacturing
# 43                 Urban_population        Total_Population_-_Female
# 42                 Urban_population          Total_Population_-_Male
# 2                     Crop_Residues          Manure_applied_to_Soils
# 19                   Food_Packaging                  Food_Processing
# 0                      Forest_fires  Fires_in_humid_tropical_forests
# 4                     Crop_Residues                 Urban_population
# 35          Manure_applied_to_Soils                 Urban_population
# 8                  Rice_Cultivation                 Rural_population
#
#     Correlation_between_vars  Var1_to_Target  Var2_to_Target
# 45                  0.999708        0.003623        0.005456
# 14                  0.985297        0.055564        0.062307
# 33                  0.975995        0.042344        0.032765
# 40                  0.974610       -0.019764        0.003623
# 41                  0.971561       -0.019764        0.005456
# 26                  0.969805        0.008995        0.005456
# 3                   0.968707        0.025365        0.032765
# 21                  0.968146        0.040767        0.062307
# 25                  0.966827        0.008995        0.003623
# 11                  0.965187        0.055564        0.040767
# 24                  0.955124        0.008995        0.036263
# 20                  0.953726        0.040767        0.041462
# 43                  0.952695        0.036263        0.005456
# 42                  0.948424        0.036263        0.003623
# 2                   0.947036        0.025365        0.042344
# 19                  0.943897        0.040767        0.053083
# 0                   0.942011       -0.039373       -0.036910
# 4                   0.941064        0.025365        0.036263
# 35                  0.939265        0.042344        0.036263
# 8                   0.937768       -0.022532       -0.019764

# %%
# === Drop highly correlated redundant variables ==========================

to_drop_vars = [
    "Total_Population_-_Male",
    "Food_Household_Consumption",
    "Manure_Management",
    "Rural_population",
    "Crop_Residues",
    "Food_Packaging",
    "Fires_in_humid_tropical_forests",
    "Rice_Cultivation"
]

df_CO2_model = df_CO2_model.drop(columns=to_drop_vars, errors="ignore")

print("Dropped variables:", to_drop_vars)
print("Remaining shape:", df_CO2_model.shape)
# Out:
# Dropped variables: ['Total_Population_-_Male', 'Food_Household_Consumption', 'Manure_Management', 'Rural_population', 'Crop_Residues', 'Food_Packaging', 'Fires_in_humid_tropical_forests', 'Rice_Cultivation']
# Remaining shape: (6965, 257)

# %%
# Dependent variable
y_name = 'Average_Temperature_°C'

# Independent variables
X_names = [col for col in df_CO2_model.columns if col != y_name]

# Define X and y
X = df_CO2_model[X_names].astype(float).to_numpy()
y = df_CO2_model[y_name].astype(float).to_numpy()

# Add constant
X = sm.add_constant(X, has_constant='add')

# %%
# Build the OLS formula string " y ~ X "
formula_str = y_name+" ~ "+" + ".join(X_names);
print('Formula:\n\t {}'.format(formula_str))
# Out:
# Formula:
# 	 Average_Temperature_°C ~ Year + Savanna_fires + Forest_fires + Drained_organic_soils_(CO2) + Pesticides_Manufacturing + Food_Transport + Forestland + Net_Forest_conversion + Food_Retail + On-farm_Electricity_Use + Agrifood_Systems_Waste_Disposal + Food_Processing + Fertilizers_Manufacturing + IPPU + Manure_applied_to_Soils + Manure_left_on_Pasture + Fires_in_organic_soils + On-farm_energy_use + Urban_population + Total_Population_-_Female + total_emission + Area_Albania + Area_Algeria + Area_American_Samoa + Area_Andorra + Area_Angola + Area_Anguilla + Area_Antigua_and_Barbuda + Area_Argentina + Area_Armenia + Area_Aruba + Area_Australia + Area_Austria + Area_Azerbaijan + Area_Bahamas + Area_Bahrain + Area_Bangladesh + Area_Barbados + Area_Belarus + Area_Belgium + Area_Belgium-Luxembourg + Area_Belize + Area_Benin + Area_Bermuda + Area_Bhutan + Area_Bolivia_(Plurinational_State_of) + Area_Bosnia_and_Herzegovina + Area_Botswana + Area_Brazil + Area_British_Virgin_Islands + Area_Brunei_Darussalam + Area_Bulgaria + Area_Burkina_Faso + Area_Burundi + Area_Cabo_Verde + Area_Cambodia + Area_Cameroon + Area_Canada + Area_Cayman_Islands + Area_Central_African_Republic + Area_Chad + Area_Channel_Islands + Area_Chile + Area_China + Area_China,_Hong_Kong_SAR + Area_China,_Macao_SAR + Area_China,_Taiwan_Province_of + Area_China,_mainland + Area_Colombia + Area_Comoros + Area_Congo + Area_Cook_Islands + Area_Costa_Rica + Area_Croatia + Area_Cuba + Area_Cyprus + Area_Czechia + Area_Czechoslovakia + Area_Democratic_People's_Republic_of_Korea + Area_Democratic_Republic_of_the_Congo + Area_Denmark + Area_Djibouti + Area_Dominica + Area_Dominican_Republic + Area_Ecuador + Area_Egypt + Area_El_Salvador + Area_Equatorial_Guinea + Area_Eritrea + Area_Estonia + Area_Eswatini + Area_Ethiopia + Area_Ethiopia_PDR + Area_Falkland_Islands_(Malvinas) + Area_Faroe_Islands + Area_Fiji + Area_Finland + Area_France + Area_French_Polynesia + Area_Gabon + Area_Gambia + Area_Georgia + Area_Germany + Area_Ghana + Area_Gibraltar + Area_Greece + Area_Greenland + Area_Grenada + Area_Guadeloupe + Area_Guam + Area_Guatemala + Area_Guinea + Area_Guinea-Bissau + Area_Guyana + Area_Haiti + Area_Holy_See + Area_Honduras + Area_Hungary + Area_Iceland + Area_India + Area_Indonesia + Area_Iran_(Islamic_Republic_of) + Area_Iraq + Area_Ireland + Area_Isle_of_Man + Area_Israel + Area_Italy + Area_Jamaica + Area_Japan + Area_Jordan + Area_Kazakhstan + Area_Kenya + Area_Kiribati + Area_Kuwait + Area_Kyrgyzstan + Area_Lao_People's_Democratic_Republic + Area_Latvia + Area_Lebanon + Area_Lesotho + Area_Liberia + Area_Libya + Area_Liechtenstein + Area_Lithuania + Area_Luxembourg + Area_Madagascar + Area_Malawi + Area_Malaysia + Area_Maldives + Area_Mali + Area_Malta + Area_Marshall_Islands + Area_Martinique + Area_Mauritania + Area_Mauritius + Area_Mayotte + Area_Mexico + Area_Micronesia_(Federated_States_of) + Area_Monaco + Area_Mongolia + Area_Montenegro + Area_Montserrat + Area_Morocco + Area_Mozambique + Area_Myanmar + Area_Namibia + Area_Nauru + Area_Nepal + Area_Netherlands_(Kingdom_of_the) + Area_Netherlands_Antilles_(former) + Area_New_Caledonia + Area_New_Zealand + Area_Nicaragua + Area_Niger + Area_Nigeria + Area_Niue + Area_North_Macedonia + Area_Northern_Mariana_Islands + Area_Norway + Area_Oman + Area_Pacific_Islands_Trust_Territory + Area_Pakistan + Area_Palau + Area_Palestine + Area_Panama + Area_Papua_New_Guinea + Area_Paraguay + Area_Peru + Area_Philippines + Area_Poland + Area_Portugal + Area_Puerto_Rico + Area_Qatar + Area_Republic_of_Korea + Area_Republic_of_Moldova + Area_Romania + Area_Russian_Federation + Area_Rwanda + Area_Saint_Helena,_Ascension_and_Tristan_da_Cunha + Area_Saint_Kitts_and_Nevis + Area_Saint_Lucia + Area_Saint_Pierre_and_Miquelon + Area_Saint_Vincent_and_the_Grenadines + Area_Samoa + Area_San_Marino + Area_Sao_Tome_and_Principe + Area_Saudi_Arabia + Area_Senegal + Area_Serbia + Area_Serbia_and_Montenegro + Area_Seychelles + Area_Sierra_Leon ...

# %%
# Fit the OLS regression
model = sm.OLS(y, X)
fitted = model.fit()

# Output the summary
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     28.91
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):               0.00
# Time:                        17:04:38   Log-Likelihood:                -3203.7
# No. Observations:                6965   AIC:                             6921.
# Df Residuals:                    6708   BIC:                             8682.
# Df Model:                         256
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -66.1650      1.168    -56.627      0.000     -68.455     -63.874
# x1             0.0334      0.001     57.255      0.000       0.032       0.035
# x2         -4.229e-06   2.93e-06     -1.441      0.150   -9.98e-06    1.52e-06
# x3          8.509e-06   4.37e-06      1.946      0.052   -6.33e-08    1.71e-05
# x4         -1.697e-06   5.11e-06     -0.332      0.740   -1.17e-05    8.32e-06
# x5         -2.202e-05   1.66e-05     -1.324      0.185   -5.46e-05    1.06e-05
# x6          1.144e-05   6.55e-06      1.746      0.081   -1.41e-06    2.43e-05
# x7          2.359e-07   1.51e-06      0.157      0.876   -2.72e-06    3.19e-06
# x8         -1.711e-07   1.54e-06     -0.111      0.912   -3.19e-06    2.85e-06
# x9         -3.764e-06   3.55e-06     -1.061      0.289   -1.07e-05    3.19e-06
# x10        -9.621e-07   4.12e-06     -0.234      0.815   -9.03e-06    7.11e-06
# x11         9.565e-06   5.45e-06      1.755      0.079   -1.12e-06    2.02e-05
# x12         -5.66e-06   2.56e-06     -2.209      0.027   -1.07e-05   -6.37e-07
# x13         1.441e-05    3.8e-06      3.789      0.000    6.95e-06    2.19e-05
# x14        -5.123e-08   1.87e-06     -0.027      0.978   -3.73e-06    3.62e-06
# x15        -8.251e-05   2.27e-05     -3.629      0.000      -0.000   -3.79e-05
# x16         9.239e-06   5.85e-06      1.578      0.115   -2.24e-06    2.07e-05
# x17        -5.706e-07   1.59e-06     -0.359      0.720   -3.69e-06    2.54e-06
# x18        -4.511e-06    4.6e-06     -0.980      0.327   -1.35e-05    4.51e-06
# x19        -1.369e-09   2.41e-09     -0.568      0.570    -6.1e-09    3.36e-09
# x20        -2.652e-09   2.69e-09     -0.987      0.324   -7.92e-09    2.62e-09
# x21         4.078e-07   1.54e-06      0.265      0.791   -2.61e-06    3.43e-06
# x218          -0.0524      0.167     -0.314      0.754      -0.380       0.275
# x219           0.4583      0.128      3.579      0.000       0.207       0.709
# x220          -0.1172      0.100     -1.169      0.242      -0.314       0.079
# x221          -0.2666      0.177     -1.507      0.132      -0.613       0.080
# x222          -0.0943      0.172     -0.548      0.584      -0.431       0.243
# x223           0.1295      0.103      1.255      0.209      -0.073       0.332
# x224           0.5668      0.108      5.237      0.000       0.355       0.779
# x225           0.5282      0.102      5.187      0.000       0.329       0.728
# x226           0.0274      0.101      0.270      0.787      -0.171       0.226
# x227           0.0354      0.102      0.346      0.729      -0.165       0.236
# x228           0.0236      0.151      0.156      0.876      -0.273       0.320
# x229          -0.2992      0.104     -2.867      0.004      -0.504      -0.095
# x230          -0.0776      0.101     -0.765      0.444      -0.276       0.121
# x231          -0.0996      0.103     -0.963      0.336      -0.302       0.103
# x232          -0.2505      0.102     -2.454      0.014      -0.451      -0.050
# x233          -0.3222      0.112     -2.882      0.004      -0.541      -0.103
# x234           0.3675      0.102      3.607      0.000       0.168       0.567
# x235           0.2851      0.104      2.748      0.006       0.082       0.489
# x236           0.0824      0.103      0.802      0.422      -0.119       0.284
# x237          -0.2576      0.102     -2.526      0.012      -0.457      -0.058
# x238           3.9600      1.195      3.315      0.001       1.618       6.302
# x239          -0.0767      0.106     -0.724      0.469      -0.284       0.131
# x240           0.5967      0.140      4.256      0.000       0.322       0.872
# x241          -0.1229      0.104     -1.182      0.237      -0.327       0.081
# x242           0.2957      0.157      1.877      0.061      -0.013       0.604
# x243          -0.2638      0.119     -2.224      0.026      -0.496      -0.031
# x244          -0.1693      0.103     -1.641      0.101      -0.372       0.033
# x245           1.3433      0.486      2.766      0.006       0.391       2.295
# x246          -0.2956      0.104     -2.830      0.005      -0.500      -0.091
# x247           0.3052      0.105      2.908      0.004       0.099       0.511
# x248          -0.3297      0.103     -3.216      0.001      -0.531      -0.129
# x249          -0.1403      0.112     -1.256      0.209      -0.359       0.079
# x250           0.0020      0.139      0.014      0.989      -0.270       0.274
# x251          -0.3038      0.103     -2.950      0.003      -0.506      -0.102
# x252           0.3942      0.104      3.788      0.000       0.190       0.598
# x253          -0.0201      0.100     -0.201      0.840      -0.216       0.176
# x254           0.0517      0.287      0.180      0.857      -0.511       0.615
# x255          -0.3141      0.141     -2.222      0.026      -0.591      -0.037
# x256          -0.5491      0.102     -5.405      0.000      -0.748      -0.350
# ==============================================================================
# Omnibus:                      578.084   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2189.896
# Skew:                          -0.356   Prob(JB):                         0.00
# Kurtosis:                       5.653   Cond. No.                     4.34e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.34e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Notes: Nothing material changed

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Variable selection by variance thresholds
#
# Variance thresholds remove **features whose values don't change much** from observation to observation.
#
# The objective here is to **remove** all features that have a **variance lower than** the selected **threshold**.
#
# **Note:** Variance is dependent on scale, so the features will have to be **normalised** before implementing variance thresholding.

# %%
# Separate data into independent (X) and independent (y) variables
X_names = list(df_CO2_copy.columns)
X_names.remove(y_name)
X_data = df_CO2_copy[X_names]
y_data = df_CO2_copy[y_name]

# %%
# Normalize data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_data)
X_normalize = pd.DataFrame(X_scaled, columns=X_data.columns)

# %% [markdown]
# ### Variance threshold in Scikit Learn
#
# To implement variance threshold in Scikit Learn we have to do the following:
#
# - Import and create an instance of the `VarianceThreshold` class.
# - Use the `.fit()` method to select a subset of features based on the threshold.

# %%
from sklearn.feature_selection import VarianceThreshold

# Create VarianceThreshold object
selector = VarianceThreshold(threshold=0.005)

# Use the object to apply the threshold on data
selector.fit(X_normalize)
# Out:
# VarianceThreshold(threshold=0.005)

# %%
# Get column variances
column_variances = selector.variances_

vars_dict = {}
vars_dict = [{"Variable_Name": c_name, "Variance": c_var}
             for c_name, c_var in zip(X_normalize.columns, column_variances)]
df_vars = pd.DataFrame(vars_dict)
df_vars.sort_values(by='Variance', ascending=False)
# Out:
#                             Variable_Name  Variance
# 0                                    Year  0.087893
# 4                        Rice_Cultivation  0.011406
# 20                      Manure_Management  0.011168
# 14        Agrifood_Systems_Waste_Disposal  0.010790
# 26                Total_Population_-_Male  0.010456
# ..                                    ...       ...
# 85                    Area_Czechoslovakia  0.000431
# 100                     Area_Ethiopia_PDR  0.000431
# 245                             Area_USSR  0.000287
# 261                     Area_Yugoslav_SFR  0.000287
# 187  Area_Pacific_Islands_Trust_Territory  0.000144
#
# [264 rows x 2 columns]

# %%
# Select new columns
X_new = X_normalize[X_normalize.columns[selector.get_support(indices=True)]]

# Save variable names for later
X_var_names = X_new.columns

# View first few entries
X_new.head()
# Out:
#        Year  Forest_fires  Crop_Residues  Rice_Cultivation  \
# 0  0.000000      0.000001       0.006139          0.004160
# 1  0.033333      0.000001       0.006255          0.004112
# 2  0.066667      0.000001       0.005868          0.004160
# 3  0.100000      0.000001       0.006892          0.004160
# 4  0.133333      0.000001       0.007227          0.004279
#
#    Pesticides_Manufacturing  Food_Transport  Forestland  \
# 0                  0.000717        0.000929    0.820811
# 1                  0.000712        0.000901    0.820811
# 2                  0.000712        0.000785    0.820811
# 3                  0.000712        0.000800    0.820811
# 4                  0.000712        0.000795    0.820811
#
#    Agrifood_Systems_Waste_Disposal  Food_Processing  Manure_applied_to_Soils  \
# 0                         0.003242          0.00092                 0.007500
# 1                         0.003331          0.00092                 0.007745
# 2                         0.003485          0.00092                 0.007634
# 3                         0.003711          0.00092                 0.007546
# 4                         0.003899          0.00092                 0.007716
#
#    Manure_left_on_Pasture  Manure_Management  Rural_population  \
# 0                0.017171           0.004515          0.010727
# 1                0.017891           0.004843          0.011366
# 2                0.017851           0.004939          0.012216
# 3                0.017737           0.004984          0.013174
# 4                0.018238           0.005202          0.014099
#
#    Urban_population  Total_Population_-_Male  Total_Population_-_Female
# 0          0.002876                 0.007192                   0.007495
# 1          0.003063                 0.007225                   0.007531
# 2          0.003310                 0.008107                   0.008451
# 3          0.003588                 0.009418                   0.009813
# 4          0.003861                 0.010400                   0.010825

# %%
X_new.shape
# Out:
# (6965, 1)

# %% [markdown]
# #### <a href=#cont>Back to Table of Contents</a>
#
# ---

# %% [markdown]
# ### 7. Modeling (H3)  <a class="anchor" id="chapter7"></a>

# %% [markdown]
# ### 8. Model Performance (H4)  <a class="anchor" id="chapter8"></a>

# %% [markdown]
# ### 9. You will learn more in Machine Learning Sprints <a class="anchor" id="chapter9"></a>

# %% [markdown]
# ## 10. Conclusion <a class="anchor" id="chapter10"></a>
#
# > <b> Summary of Key Findings:</b> Recap the main insights and results discovered through the analysis. Highlight how these findings answer the initial questions or hypotheses set out in the introduction.
#
# > <b> Evaluation of the Methodology:</b> Discuss the effectiveness of the methods and techniques used. Mention any limitations or challenges encountered during the analysis and how they were addressed or could be addressed in the future.
#
# > <b> Implications of the Findings:</b> Explain the practical or theoretical implications of the results.Discuss how these findings can impact decision-making processes, policy, business strategies, or scientific understanding.
#
# > <b> Suggestions for Future Work:</b> Propose areas for further research or additional questions that emerged from the project. Suggest improvements in data collection, analysis methods, or other aspects that could enhance future studies.
#
# > <b> Reflection on the Data Source and Quality:</b> Reflect on the quality and reliability of the data used. Consider how the data source influenced the outcomes and what could be improved in terms of data quality or variety.
#
# > <b>Concluding Thoughts:</b> Offer a final thought or summary statement that encapsulates the essence of the project and its impact. Encourage readers to consider broader applications or the next steps following from the project’s conclusions.

# %% [markdown]
# #### <a href=#cont>Back to Table of Contents</a>
#
# ---

# %% [markdown]
# ## 11. References <a class="anchor" id="chapter11"></a>

# %% [markdown]
# Maintaining clear and organized documentation is crucial for reproducibility and credibility. Harvard referencing, a widely recognized citation style, can be effectively applied to data science notebooks to ensure proper acknowledgment of sources and facilitate the tracing of data and methodologies back to their origins.

# %% [markdown]
# 1. Citing Data Sources: When gathering datasets for analysis, it's essential to cite the origin of the data. This includes providing details such as the author, publication date, title, and source of the dataset. In your notebook, you can include inline citations for each dataset you use, following the Harvard referencing format.
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> The World Bank. (2020). World Development Indicators. Retrieved from https://datacatalog.worldbank.org/dataset/world-development-indicators
# </div>
#
# 2. Referencing Research Papers: Data science often involves building upon existing research. Whether you're utilizing algorithms, methodologies, or theories from academic papers, it's important to reference them properly. Include citations for relevant papers within your notebook, both in the narrative sections and within code comments where applicable.
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Smith, J., & Doe, A. (2018). Predictive Modeling Techniques for Financial Forecasting. Journal of Data Science, 10(2), 123-135.
# </div>
#
# 3. Code Libraries and Packages: Data science projects heavily rely on various libraries and packages for analysis and visualization. When utilizing third-party code, make sure to acknowledge the creators by referencing the relevant documentation or papers associated with those tools.
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Matplotlib Development Team. (2020). Matplotlib: A 2D plotting library. Retrieved from https://matplotlib.org/
# </div>
#
# 4. Acknowledging Scholarly Contributions: If you've consulted online forums, blogs, or other informal resources during your project, it's courteous to acknowledge these contributions. While Harvard referencing is traditionally used for academic sources, you can adapt it to reference online resources as well.
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Kaggle. (2021). Titanic: Machine Learning from Disaster. Retrieved from https://www.kaggle.com/c/titanic
# </div>

# %% [markdown]
# #### <a href=#cont>Back to Table of Contents</a>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Another thing to consider:</b> Take a look at the notebooks uploaded on Athena to explore different methods for incorporating specific elements into your own notebooks.
# </div>
